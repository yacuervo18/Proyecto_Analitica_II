# %%
from pathlib import Path
import pandas as pd

# %%
#Obtener la raíz del proyecto (subiendo un nivel desde la carpeta src/)
proyecto_root = Path.cwd().parent

# Ruta a la carpeta data
data_dir = proyecto_root / "data"

# Leer uno de los archivos (ajusta el separador según tu archivo)
df_exposicion = pd.read_csv(data_dir / "BD_Exposicion.txt", sep="\t")  # o sep=',' o sep=';'

# Ver las primeras filas
df_exposicion.head()
# Out:
#    Asegurado_Id  Poliza_Asegurado_Id FECHA_INICIO FECHA_CANCELACION  \
# 0      61630146            271191574   29/01/2024        29/06/2024
# 1       7966225            283714899   13/11/2024               NaN
# 2       3124492             50801309    1/01/2024        17/01/2024
# 3      11863430            236507980    1/01/2024               NaN
# 4       4345756            230314288    1/01/2024               NaN
#
#     FECHA_FIN
# 0  29/06/2024
# 1  31/12/2024
# 2  17/01/2024
# 3  31/12/2024
# 4  31/12/2024
